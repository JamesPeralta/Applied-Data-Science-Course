# %% [markdown]
# # ENSF 519.01 Applied Data Science
# **Assignment 2** - 100 marks
#
# **Due:** October 18th, 04.00 pm.
#
#
# **IMPORTANT NOTE: each task must be implemented as asked, even if there are other easier or better solutions.**
#
# **How to deliver:**
# Edit this file and write your solutions in sections specified with `# Your solution`. Test your code and when you are done, submit this notebook as an `.ipynb` file to D2L dropbox.

# %% [markdown]
# ## Problem 1 - Most popular movies (55 points)
# In this assigment we want to do some basic data analysis on the most popular movies on IMDb right now. We do this in steps: first we take the list of most popular movies then we gather more informaion on each movie from the movie's page. These info are stored in pandas dataframes. Next we need to combine the information from these two tables, using pandas `merge` method. The resulting merged table might give us some insight on why some movies get more popular. Let's try and see what we can get!
#
# Complete the `get_page_html` function below so that it gets the HTML content of any given url. We get the HTML content and store it in a variable just once, because:
# 1. Downloading the web page content takes ~1-2 seconds. While you're writing the html parser code you need to run and test your code many many times. If you download the whole page everytime you want to test the parser, these download times add up to significantly slow you down.
# 2. Making a lot of requests to the same page of a website in a short period of time might make the firewall suspicious of an attack and block your IP address

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

page_url = 'https://www.imdb.com/chart/top'

def get_page_html(url):
    return requests.get(url).text
    
top_movies_html = get_page_html(page_url)

# %% [markdown]
# Parse the HTML content above using Beautiful Soup to extract these data:
#
# * Rank (`rank`: int) **set this column as the index**
# * Name of the movie (`name`: str)
# * Its release year (`release_year`: int)
# * Rating (`rating`: float)
# * link to its detail page (`detail_url`: str)
#
# Store these in a pandas dataframe. The suggested column names and data types are specified in the parentheses above (20 points).

# %%
def get_top_movies(top_movies_page_html):    
    parser = BeautifulSoup(top_movies_page_html, 'html.parser')
    the_table = parser.select('table.chart')[0]
    data = {
        'rank': [],
        'name': [],
        'release_year': [],
        'rating': [],
        'detail_url': [],
    }
    for row in the_table.tbody.find_all('tr'):
        # each row is a <tr>
        rating_text = row.find('td', class_='imdbRating').get_text().strip()
        if rating_text:
            data['rating'].append(float(rating_text))
        else:
            data['rating'].append(np.NaN)            

        title_col = row.find_all('td', class_='titleColumn')[0]
        name_link = title_col.a
        data['name'].append(name_link.string)
        data['detail_url'].append(name_link['href'])
        data['release_year'].append(int(title_col.find_all(class_='secondaryInfo', limit=1)[0].string[1:-1]))
        data['rank'].append(int(title_col.get_text().strip().split('.', 2)[0]))
    
    df = pd.DataFrame.from_dict(data)
    df.set_index('rank', inplace=True)
    return df

top_movies = get_top_movies(top_movies_html)
top_movies  # Rank must be the index, the rows should match the webpage
# Out:
#                                                    name  release_year  rating  \
# rank
# 1                              The Shawshank Redemption          1994     9.2
# 2                                         The Godfather          1972     9.1
# 3                                The Godfather: Part II          1974     9.0
# 4                                       The Dark Knight          2008     9.0
# 5                                          12 Angry Men          1957     8.9
# 6                                      Schindler's List          1993     8.9
# 7         The Lord of the Rings: The Return of the King          2003     8.9
# 8                                          Pulp Fiction          1994     8.9
# 9                       Il buono, il brutto, il cattivo          1966     8.8
# 10                                           Fight Club          1999     8.8
# 11    The Lord of the Rings: The Fellowship of the Ring          2001     8.8
# 12                                         Forrest Gump          1994     8.8
# 13                                                Joker          2019     8.7
# 14                                            Inception          2010     8.7
# 15       Star Wars: Episode V - The Empire Strikes Back          1980     8.7
# 16                The Lord of the Rings: The Two Towers          2002     8.7
# 17                                           The Matrix          1999     8.6
# 18                      One Flew Over the Cuckoo's Nest          1975     8.6
# 19                                           Goodfellas          1990     8.6
# 20                                 Shichinin no samurai          1954     8.6
# 21                                                Se7en          1995     8.6
# 22                                       Cidade de Deus          2002     8.6
# 23                                      La vita è bella          1997     8.6
# 24                             The Silence of the Lambs          1991     8.6
# 25                                It's a Wonderful Life          1946     8.6
# 26                                            Star Wars          1977     8.6
# 27                                  Saving Private Ryan          1998     8.5
# 28                        Sen to Chihiro no kamikakushi          2001     8.5
# 29                                       The Green Mile          1999     8.5
# 30                                                 Léon          1994     8.5
# ...                                                 ...           ...     ...
# 221                              Les quatre cents coups          1959     8.0
# 222                                           Spotlight          2015     8.0
# 223                                     Ace in the Hole          1951     8.0
# 224                                  Dead Poets Society          1989     8.0
# 225                                             Rebecca          1940     8.0
# 226                                               Rocky          1976     8.0
# 227                                      Monsters, Inc.          2001     8.0
# 228                               It Happened One Night          1934     8.0
# 229                                  Gangs of Wasseypur          2012     8.0
# 230                                            La haine          1995     8.0
# 231                                           Ah-ga-ssi          2016     8.0
# 232                   Lagaan: Once Upon a Time in India          2001     8.0
# 233                                  The Princess Bride          1987     8.0
# 234                                 Munna Bhai M.B.B.S.          2003     8.0
# 235                                                  PK          2014     8.0
# 236                  Butch Cassidy and the Sundance Kid          1969     8.0
# 237                                       Before Sunset          2004     8.0
# 238                                            The Help          2011     8.0
# 239                              Swades: We, the People          2004     8.0
# 240                                               Akira          1988     8.0
# 241                                      The Terminator          1984     8.0
# 242                                    Faa yeung nin wa          2000     8.0
# 243                                        Paris, Texas          1984     8.0
# 244                               El ángel exterminador          1962     8.0
# 245                                             Aladdin          1992     8.0
# 246                             Guardians of the Galaxy          2014     8.0
# 247                                        Mou gaan dou          2002     8.0
# 248                              La battaglia di Algeri          1966     8.0
# 249                              Tenkû no shiro Rapyuta          1986     8.0
# 250                                         Kumonosu-jô          1957     8.0
#
#              detail_url
# rank
# 1     /title/tt0111161/
# 2     /title/tt0068646/
# 3     /title/tt0071562/
# 4     /title/tt0468569/
# 5     /title/tt0050083/
# 6     /title/tt0108052/
# 7     /title/tt0167260/
# 8     /title/tt0110912/
# 9     /title/tt0060196/
# 10    /title/tt0137523/
# 11    /title/tt0120737/
# 12    /title/tt0109830/
# 13    /title/tt7286456/
# 14    /title/tt1375666/
# 15    /title/tt0080684/
# 16    /title/tt0167261/
# 17    /title/tt0133093/
# 18    /title/tt0073486/
# 19    /title/tt0099685/
# 20    /title/tt0047478/
# 21    /title/tt0114369/
# 22    /title/tt0317248/
# 23    /title/tt0118799/
# 24    /title/tt0102926/
# 25    /title/tt0038650/
# 26    /title/tt0076759/
# 27    /title/tt0120815/
# 28    /title/tt0245429/
# 29    /title/tt0120689/
# 30    /title/tt0110413/
# ...                 ...
# 221   /title/tt0053198/
# 222   /title/tt1895587/
# 223   /title/tt0043338/
# 224   /title/tt0097165/
# 225   /title/tt0032976/
# 226   /title/tt0075148/
# 227   /title/tt0198781/
# 228   /title/tt0025316/
# 229   /title/tt1954470/
# 230   /title/tt0113247/
# 231   /title/tt4016934/
# 232   /title/tt0169102/
# 233   /title/tt0093779/
# 234   /title/tt0374887/
# 235   /title/tt2338151/
# 236   /title/tt0064115/
# 237   /title/tt0381681/
# 238   /title/tt1454029/
# 239   /title/tt0367110/
# 240   /title/tt0094625/
# 241   /title/tt0088247/
# 242   /title/tt0118694/
# 243   /title/tt0087884/
# 244   /title/tt0056732/
# 245   /title/tt0103639/
# 246   /title/tt2015381/
# 247   /title/tt0338564/
# 248   /title/tt0058946/
# 249   /title/tt0092067/
# 250   /title/tt0050613/
#
# [250 rows x 4 columns]

# %% [markdown]
# Now we proceed to step 2, we want to create a function that parses each individual movie's page. Just like the previous assignment on regular expressions, we try to get that working on one sample and only after we made sure that everything works properly we use a loop to get all the data that we need.

# %%
avengers_url = 'https://www.imdb.com/title/tt4154796/'
avengers_html = get_page_html(avengers_url)

# %% [markdown]
# Make a function that parses the html content of a movie details page and extracts these information:
#
# * Movie length in minutes (int)
# * Release date (convert the string to a python date object - use [`strptime` built-in function](https://www.programiz.com/python-programming/datetime/strptime) or regular expressions as you wish)
# * List of genres (list of strings)
# * Budget (int), if unavailable: ignore.
# * Name of the directors (list)
#
# Return these as a dictionary. You can extract more data as you wish. (20 points)

# %%
import re
from datetime import datetime 

def extract_movie_details(html):
    parser = BeautifulSoup(html, 'html.parser')
    subtext = parser.select('.title_wrapper .subtext')[0]
    
    time = int(subtext.time.attrs['datetime'][2:-1])
    
    genres = [link.get_text() for link in subtext.find_all('a', href=re.compile('^/search/title\?genres='))]
    
    try:
        release_date_string = subtext.find('a', title='See more release dates').get_text()
        release_date_string = re.search('\d+ \w+ \d+', release_date_string)
        if release_date_string:
            release_date = datetime.strptime(release_date_string[0], '%d %B %Y')
        else:
            release_date_string = re.search('\d+', release_date_string)[0]
            release_date = datetime.datetime(year=int(release_date_string), month=1, day=1)
    except:
        release_date = np.NaN
    
    for credit_item in parser.find_all('div', class_='credit_summary_item'):
        t = credit_item.h4.get_text().strip()
        if t.startswith('Director'):
            directors = [link.get_text() for link in credit_item.find_all('a')]
            break
    
    try:
        budget = re.search('\$(\d+,?)+', parser\
            .find('h3', class_='subheading', string='Box Office')\
            .find_next_siblings(lambda tag: \
                                tag.name=='div' and \
                                tag.h4.get_text().strip().startswith('Budget'), limit=1)[0].get_text())[0]
        budget = int(budget.replace('$', '').replace(',', ''))
    except:
        budget = np.NaN

    data = {
        'length': time,
        'genres': genres,
        'release_date': release_date,
        'budget': budget,
        'directors': directors,
    }
    return data
    
    
avengers_data = extract_movie_details(avengers_html)
print(avengers_data) 
# Expected: {
#     'length': 181, 
#     'genres': ['action', 'adventure', 'sci-fi'], 
#     'release_date': datetime.datetime(2019, 4, 26, 0, 0),
#     'budget': 356000000,
#     'directors': ['Anthony Russo', 'Joe Russo']
# }
# Out:
# {'length': 181, 'genres': ['Action', 'Adventure', 'Drama'], 'release_date': datetime.datetime(2019, 4, 26, 0, 0), 'budget': 356000000, 'directors': ['Anthony Russo', 'Joe Russo']}

# %% [markdown]
# Now get the list of detail page urls for all the movies:

# %%
urls = top_movies.set_index('name')['detail_url']
urls
# Out:
# name
# The Shawshank Redemption                             /title/tt0111161/
# The Godfather                                        /title/tt0068646/
# The Godfather: Part II                               /title/tt0071562/
# The Dark Knight                                      /title/tt0468569/
# 12 Angry Men                                         /title/tt0050083/
# Schindler's List                                     /title/tt0108052/
# The Lord of the Rings: The Return of the King        /title/tt0167260/
# Pulp Fiction                                         /title/tt0110912/
# Il buono, il brutto, il cattivo                      /title/tt0060196/
# Fight Club                                           /title/tt0137523/
# The Lord of the Rings: The Fellowship of the Ring    /title/tt0120737/
# Forrest Gump                                         /title/tt0109830/
# Joker                                                /title/tt7286456/
# Inception                                            /title/tt1375666/
# Star Wars: Episode V - The Empire Strikes Back       /title/tt0080684/
# The Lord of the Rings: The Two Towers                /title/tt0167261/
# The Matrix                                           /title/tt0133093/
# One Flew Over the Cuckoo's Nest                      /title/tt0073486/
# Goodfellas                                           /title/tt0099685/
# Shichinin no samurai                                 /title/tt0047478/
# Se7en                                                /title/tt0114369/
# Cidade de Deus                                       /title/tt0317248/
# La vita è bella                                      /title/tt0118799/
# The Silence of the Lambs                             /title/tt0102926/
# It's a Wonderful Life                                /title/tt0038650/
# Star Wars                                            /title/tt0076759/
# Saving Private Ryan                                  /title/tt0120815/
# Sen to Chihiro no kamikakushi                        /title/tt0245429/
# The Green Mile                                       /title/tt0120689/
# Léon                                                 /title/tt0110413/
#                                                            ...
# Les quatre cents coups                               /title/tt0053198/
# Spotlight                                            /title/tt1895587/
# Ace in the Hole                                      /title/tt0043338/
# Dead Poets Society                                   /title/tt0097165/
# Rebecca                                              /title/tt0032976/
# Rocky                                                /title/tt0075148/
# Monsters, Inc.                                       /title/tt0198781/
# It Happened One Night                                /title/tt0025316/
# Gangs of Wasseypur                                   /title/tt1954470/
# La haine                                             /title/tt0113247/
# Ah-ga-ssi                                            /title/tt4016934/
# Lagaan: Once Upon a Time in India                    /title/tt0169102/
# The Princess Bride                                   /title/tt0093779/
# Munna Bhai M.B.B.S.                                  /title/tt0374887/
# PK                                                   /title/tt2338151/
# Butch Cassidy and the Sundance Kid                   /title/tt0064115/
# Before Sunset                                        /title/tt0381681/
# The Help                                             /title/tt1454029/
# Swades: We, the People                               /title/tt0367110/
# Akira                                                /title/tt0094625/
# The Terminator                                       /title/tt0088247/
# Faa yeung nin wa                                     /title/tt0118694/
# Paris, Texas                                         /title/tt0087884/
# El ángel exterminador                                /title/tt0056732/
# Aladdin                                              /title/tt0103639/
# Guardians of the Galaxy                              /title/tt2015381/
# Mou gaan dou                                         /title/tt0338564/
# La battaglia di Algeri                               /title/tt0058946/
# Tenkû no shiro Rapyuta                               /title/tt0092067/
# Kumonosu-jô                                          /title/tt0050613/
# Name: detail_url, Length: 250, dtype: object

# %% [markdown]
# and loop through the movie name and urls created above (`urls`), use `extract_movie_details` and create a data frame out of the dictionaries. The dataframe should have a column storing the movie name and one column for each item in the dictionary (length, genres, ...). If any piece of data was not availble for a movie (e.g. budget might not be available for some) just leave it, pandas will use `NaN` for that cell. (10 points)

# %%
page_contents = []
for name, url in urls.iteritems():
    full_url = f'https://imdb.com{url}'
    page_contents.append(get_page_html(full_url))

# %%
movie_details_list = []
for content, (name, url) in zip(page_contents, urls.iteritems()):
    details = extract_movie_details(content)
    details['name'] = name
    movie_details_list.append(details)

# %%
movie_details = pd.DataFrame(data=movie_details_list)

# %% [markdown]
# Use pandas' `merge` method to join these two tables into one. Merge on movie name. (5 points)

# %%
merged = pd.merge(
    # Your solution
)
merged

# %%
merged = pd.merge(top_movies, movie_details, how='left', on='name')

# import json
# merged = pd.read_csv('movies.csv')
# merged['release_date'] = pd.to_datetime(merged.release_date, format='%Y-%m-%d')
# merged['genres'] = merged.genres.apply(lambda x: None if not x else json.loads(x.replace("'", '"')))
# merged['directors'] = merged.directors.apply(lambda x: None if not x else json.loads(x.replace("', '", '", "').replace("['", '["').replace("']", '"]')))
# merged.set_index('Unnamed: 0', inplace=True)
merged
# Out:
#                                                   name  release_year  rating  \
# 0                             The Shawshank Redemption          1994     9.2
# 1                                        The Godfather          1972     9.1
# 2                               The Godfather: Part II          1974     9.0
# 3                                      The Dark Knight          2008     9.0
# 4                                         12 Angry Men          1957     8.9
# 5                                     Schindler's List          1993     8.9
# 6        The Lord of the Rings: The Return of the King          2003     8.9
# 7                                         Pulp Fiction          1994     8.9
# 8                      Il buono, il brutto, il cattivo          1966     8.8
# 9                                           Fight Club          1999     8.8
# 10   The Lord of the Rings: The Fellowship of the Ring          2001     8.8
# 11                                        Forrest Gump          1994     8.8
# 12                                               Joker          2019     8.7
# 13                                           Inception          2010     8.7
# 14      Star Wars: Episode V - The Empire Strikes Back          1980     8.7
# 15               The Lord of the Rings: The Two Towers          2002     8.7
# 16                                          The Matrix          1999     8.6
# 17                     One Flew Over the Cuckoo's Nest          1975     8.6
# 18                                          Goodfellas          1990     8.6
# 19                                Shichinin no samurai          1954     8.6
# 20                                               Se7en          1995     8.6
# 21                                      Cidade de Deus          2002     8.6
# 22                                     La vita è bella          1997     8.6
# 23                            The Silence of the Lambs          1991     8.6
# 24                               It's a Wonderful Life          1946     8.6
# 25                                           Star Wars          1977     8.6
# 26                                 Saving Private Ryan          1998     8.5
# 27                       Sen to Chihiro no kamikakushi          2001     8.5
# 28                                      The Green Mile          1999     8.5
# 29                                                Léon          1994     8.5
# ..                                                 ...           ...     ...
# 220                             Les quatre cents coups          1959     8.0
# 221                                          Spotlight          2015     8.0
# 222                                    Ace in the Hole          1951     8.0
# 223                                 Dead Poets Society          1989     8.0
# 224                                            Rebecca          1940     8.0
# 225                                              Rocky          1976     8.0
# 226                                     Monsters, Inc.          2001     8.0
# 227                              It Happened One Night          1934     8.0
# 228                                 Gangs of Wasseypur          2012     8.0
# 229                                           La haine          1995     8.0
# 230                                          Ah-ga-ssi          2016     8.0
# 231                  Lagaan: Once Upon a Time in India          2001     8.0
# 232                                 The Princess Bride          1987     8.0
# 233                                Munna Bhai M.B.B.S.          2003     8.0
# 234                                                 PK          2014     8.0
# 235                 Butch Cassidy and the Sundance Kid          1969     8.0
# 236                                      Before Sunset          2004     8.0
# 237                                           The Help          2011     8.0
# 238                             Swades: We, the People          2004     8.0
# 239                                              Akira          1988     8.0
# 240                                     The Terminator          1984     8.0
# 241                                   Faa yeung nin wa          2000     8.0
# 242                                       Paris, Texas          1984     8.0
# 243                              El ángel exterminador          1962     8.0
# 244                                            Aladdin          1992     8.0
# 245                            Guardians of the Galaxy          2014     8.0
# 246                                       Mou gaan dou          2002     8.0
# 247                             La battaglia di Algeri          1966     8.0
# 248                             Tenkû no shiro Rapyuta          1986     8.0
# 249                                        Kumonosu-jô          1957     8.0
#
#             detail_url       budget  \
# 0    /title/tt0111161/   25000000.0
# 1    /title/tt0068646/    6000000.0
# 2    /title/tt0071562/   13000000.0
# 3    /title/tt0468569/  185000000.0
# 4    /title/tt0050083/     350000.0
# 5    /title/tt0108052/   22000000.0
# 6    /title/tt0167260/   94000000.0
# 7    /title/tt0110912/    8000000.0
# 8    /title/tt0060196/    1200000.0
# 9    /title/tt0137523/   63000000.0
# 10   /title/tt0120737/   93000000.0
# 11   /title/tt0109830/   55000000.0
# 12   /title/tt7286456/   55000000.0
# 13   /title/tt1375666/  160000000.0
# 14   /title/tt0080684/   18000000.0
# 15   /title/tt0167261/   94000000.0
# 16   /title/tt0133093/   63000000.0
# 17   /title/tt0073486/    3000000.0
# 18   /title/tt0099685/   25000000.0
# 19   /title/tt0047478/          NaN
# 20   /title/tt0114369/   33000000.0
# 21   /title/tt0317248/    3300000.0
# 22   /title/tt0118799/   20000000.0
# 23   /title/tt0102926/   19000000.0
# 24   /title/tt0038650/    3180000.0
# 25   /title/tt0076759/   11000000.0
# 26   /title/tt0120815/   70000000.0
# 27   /title/tt0245429/   19000000.0
# 28   /title/tt0120689/   60000000.0
# 29   /title/tt0110413/          NaN
# ..                 ...          ...
# 220  /title/tt0053198/          NaN
# 221  /title/tt1895587/   20000000.0
# 222  /title/tt0043338/    1800000.0
# 223  /title/tt0097165/   16400000.0
# 224  /title/tt0032976/    1288000.0
# 225  /title/tt0075148/     960000.0
# 226  /title/tt0198781/  115000000.0
# 227  /title/tt0025316/     325000.0
# 228  /title/tt1954470/          NaN
# 229  /title/tt0113247/          NaN
# 230  /title/tt4016934/          NaN
# 231  /title/tt0169102/    6000000.0
# 232  /title/tt0093779/   16000000.0
# 233  /title/tt0374887/          NaN
# 234  /title/tt2338151/          NaN
# 235  /title/tt0064115/    6000000.0
# 236  /title/tt0381681/    2700000.0
# 237  /title/tt1454029/   25000000.0
# 238  /title/tt0367110/          NaN
# 239  /title/tt0094625/          NaN
# 240  /title/tt0088247/    6400000.0
# 241  /title/tt0118694/          NaN
# 242  /title/tt0087884/          NaN
# 243  /title/tt0056732/          NaN
# 244  /title/tt0103639/   28000000.0
# 245  /title/tt2015381/  170000000.0
# 246  /title/tt0338564/    6428966.0
# 247  /title/tt0058946/     800000.0
# 248  /title/tt0092067/          NaN
# 249  /title/tt0050613/          NaN
#
#                                          directors  \
# 0                                 [Frank Darabont]
# 1                           [Francis Ford Coppola]
# 2                           [Francis Ford Coppola]
# 3                              [Christopher Nolan]
# 4                                   [Sidney Lumet]
# 5                               [Steven Spielberg]
# 6                                  [Peter Jackson]
# 7                              [Quentin Tarantino]
# 8                                   [Sergio Leone]
# 9                                  [David Fincher]
# 10                                 [Peter Jackson]
# 11                               [Robert Zemeckis]
# 12                                 [Todd Phillips]
# 13                             [Christopher Nolan]
# 14                                [Irvin Kershner]
# 15                                 [Peter Jackson]
# 16               [Lana Wachowski, Lilly Wachowski]
# 17                                  [Milos Forman]
# 18                               [Martin Scorsese]
# 19                                [Akira Kurosawa]
# 20                                 [David Fincher]
# 21                [Fernando Meirelles, Kátia Lund]
# 22                               [Roberto Benigni]
# 23                                [Jonathan Demme]
# 24                                   [Frank Capra]
# 25                                  [George Lucas]
# 26                              [Steven Spielberg]
# 27                                [Hayao Miyazaki]
# 28                                [Frank Darabont]
# 29                                    [Luc Besson]
# ..                                             ...
# 220                            [François Truffaut]
# 221                                 [Tom McCarthy]
# 222                                 [Billy Wilder]
# 223                                   [Peter Weir]
# 224                             [Alfred Hitchcock]
# 225                             [John G. Avildsen]
# 226  [Pete Docter, David Silverman, 1 more credit]
# 227                                  [Frank Capra]
# 228                               [Anurag Kashyap]
# 229                            [Mathieu Kassovitz]
# 230                               [Chan-wook Park]
# 231                           [Ashutosh Gowariker]
# 232                                   [Rob Reiner]
# 233                              [Rajkumar Hirani]
# 234                              [Rajkumar Hirani]
# 235                              [George Roy Hill]
# 236                            [Richard Linklater]
# 237                                  [Tate Taylor]
# 238                           [Ashutosh Gowariker]
# 239                              [Katsuhiro Ôtomo]
# 240                                [James Cameron]
# 241                                 [Kar-Wai Wong]
# 242                                  [Wim Wenders]
# 243                                  [Luis Buñuel]
# 244                    [Ron Clements, John Musker]
# 245                                   [James Gunn]
# 246                         [Andrew Lau, Alan Mak]
# 247                             [Gillo Pontecorvo]
# 248                               [Hayao Miyazaki]
# 249                               [Akira Kurosawa]
#
#                              genres  length release_date
# 0                           [Drama]     142   1994-10-14
# 1                    [Crime, Drama]     175   1972-03-24
# 2                    [Crime, Drama]     202   1974-12-20
# 3            [Action, Crime, Drama]     152   2008-07-18
# 4                           [Drama]      96   1957-04-10
# 5       [Biography, Drama, History]     195   1993-12-25
# 6       [Adventure, Drama, Fantasy]     201   2003-12-17
# 7                    [Crime, Drama]     154   1994-10-14
# 8                         [Western]     161   1966-12-23
# 9                           [Drama]     139   1999-10-15
# 10      [Adventure, Drama, Fantasy]     178   2001-12-19
# 11                 [Drama, Romance]     142   1994-07-06
# 12         [Crime, Drama, Thriller]     122   2019-10-04
# 13      [Action, Adventure, Sci-Fi]     148   2010-07-16
# 14     [Action, Adventure, Fantasy]     124   1980-06-20
# 15      [Adventure, Drama, Fantasy]     179   2002-12-18
# 16                 [Action, Sci-Fi]     136   1999-03-31
# 17                          [Drama]     133   1975-11-19
# 18        [Biography, Crime, Drama]     146   1990-09-21
# 19               [Adventure, Drama]     207   1954-04-26
# 20          [Crime, Drama, Mystery]     127   1995-09-22
# 21                   [Crime, Drama]     130   2002-08-30
# 22         [Comedy, Drama, Romance]     116   1998-11-06
# 23         [Crime, Drama, Thriller]     118   1991-02-14
# 24         [Drama, Family, Fantasy]     130   1947-01-07
# 25     [Action, Adventure, Fantasy]     121   1977-05-25
# 26                     [Drama, War]     169   1998-07-24
# 27   [Animation, Adventure, Family]     125   2001-07-20
# 28          [Crime, Drama, Fantasy]     189   1999-12-10
# 29           [Action, Crime, Drama]     110   1994-09-14
# ..                              ...     ...          ...
# 220                  [Crime, Drama]      99   1959-06-03
# 221       [Biography, Crime, Drama]     129   2015-11-20
# 222              [Drama, Film-Noir]     111   1951-07-04
# 223                 [Comedy, Drama]     128   1989-06-09
# 224       [Drama, Mystery, Romance]     130   1940-04-12
# 225                  [Drama, Sport]     120   1976-12-03
# 226  [Animation, Adventure, Comedy]      92   2001-11-02
# 227               [Comedy, Romance]     105   1934-02-22
# 228         [Action, Comedy, Crime]     321   2012-08-02
# 229                  [Crime, Drama]      98   1995-09-01
# 230      [Drama, Romance, Thriller]     145   2016-10-28
# 231     [Adventure, Drama, Musical]     224   2001-06-15
# 232    [Adventure, Family, Fantasy]      98   1987-10-09
# 233        [Comedy, Drama, Musical]     156   2003-12-19
# 234        [Comedy, Drama, Fantasy]     153   2014-12-19
# 235       [Biography, Crime, Drama]     110   1969-09-24
# 236                [Drama, Romance]      80   2004-07-30
# 237                         [Drama]     146   2011-08-10
# 238                         [Drama]     210   2004-12-17
# 239      [Animation, Drama, Sci-Fi]     124   1988-07-16
# 240                [Action, Sci-Fi]     107   1984-10-26
# 241                [Drama, Romance]      98   2000-09-29
# 242                         [Drama]     145   1984-09-19
# 243                [Drama, Fantasy]      95   1966-09-22
# 244  [Animation, Adventure, Comedy]      90   1992-12-25
# 245     [Action, Adventure, Comedy]     121   2014-08-01
# 246         [Crime, Drama, Mystery]     101   2002-12-12
# 247                    [Drama, War]     121   1967-02-25
# 248   [Animation, Adventure, Drama]     125   1986-08-02
# 249                [Drama, History]     110   1957-01-15
#
# [250 rows x 9 columns]

# %% [markdown]
# # Problem 2 - Visualizing and Analysing (45 points)
#
# Now, we have a data frame containing information about the most popular IMDb movies as of now. In this part we are going to use matplotlib to visualize those data and see if we can find any meaningful features that can predict success of a movie.
#
# This problem uses the results of the problem 1. If you can't do Problem 1 for any reason, we have a csv file uploaded on D2L that contains the final result of Problem 1. You can download that file and use `pd.read_csv` to create a dataframe from it. Please note that you need to convert the release date from an string to a datetime object. Also you need to parse the `genres` and `directors` columns into python lists.
#
# ## Releasing Season and Year
# First, create a column that contains which season the movie was released in, if data isn't available ignore that row. Then use pandas aggregation methods to count the movies released in each season of the year. Plot a [bar chart](https://matplotlib.org/3.1.1/gallery/lines_bars_and_markers/barchart.html#sphx-glr-gallery-lines-bars-and-markers-barchart-py) that shows the average rating of movies made in each season per year for the last **20 years**. Show the 4 seasons of each year next to each other. Use the ticks on X axis to show the year and the colours of the bars to show the season. Also, put a legend on the chart. (10 points)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

df = merged.loc[merged.release_year >= 2019-20,:].copy()

def get_season(date):
    if not date:
        return None
    elif date.month in [12, 1, 2]:
        return 'winter'
    elif 3<=date.month<=5:
        return 'spring'
    elif 6<=date.month<=8:
        return 'summer'
    else:
        return 'fall'


df['season'] = df['release_date'].apply(get_season)
grouped = df.groupby(['release_year', 'season'])['rating'].mean().reset_index()

fig = plt.figure(figsize=(20, 6))
ax = fig.add_subplot(111)
w = 0.35
for s, c, offset in [('winter','b', -2*w/4), ('spring', 'g', -w/4), ('summer', 'r', +w/4), ('fall', 'orange', +2*w/4)]:
    filtered = grouped[grouped['season'] == s]
    ax.bar(filtered['release_year']+offset, filtered['rating'], color=c, label=s, width=w/4)

ax.set_xticks(np.arange(df['release_year'].min(), df['release_year'].max()+1, 1))
ax.legend();

# %% [markdown]
# ## Genre and Directors
#
# Create two pie charts in a figure next to each other. In one, plot the number of movies in each genre and in the other, plot the number of movies directed by each director. Since there are many directors only keep the people who have directed 3 movies or more. First create two dataframes for the charts. One should have two columns:
# * genre (set as **index**)
# * count_ratings
# * mean_ratings (**sort the dataframe** by this column in decending order)
#
# and the other one:
# * name (set as **index**)
# * count_movies (**sort the dataframe** by this column in decending order)
#
# After making the dataframes you can proceed to drawing the two [pie charts](https://matplotlib.org/3.1.1/gallery/pie_and_polar_charts/pie_features.html#sphx-glr-gallery-pie-and-polar-charts-pie-features-py) based on them. Sorting the table before drawing the charts make the slices sorted, try drawing charts for the same data but comment out the line of code you wrote for sorting and see the difference. Make an appropriate title for each chart, also show the name of each genre/each director next to each pie slice. (20 points)

# %%
df = merged 

all_genres = set(genre for g in df['genres'] for genre in g)

stats = []
for genre in all_genres:
    sub_frame = df.loc[df['genres'].apply(lambda row: genre in row), 'rating']
    stats.append([genre, sub_frame.count(), sub_frame.mean()])

genre_stats = pd.DataFrame(columns=['genre', 'count_ratings', 'mean_ratings'], data=stats)
genre_stats.set_index('genre', inplace=True)
genre_stats.sort_values(by='mean_ratings', inplace=True, ascending=False)
genre_stats
# Out:
#            count_ratings  mean_ratings
# genre
# Western                6      8.366667
# Horror                 4      8.350000
# Fantasy               19      8.342105
# Music                  4      8.325000
# Action                36      8.283333
# Crime                 53      8.279245
# Family                13      8.276923
# Sci-Fi                23      8.273913
# Adventure             57      8.270175
# Drama                181      8.256906
# War                   16      8.256250
# Mystery               25      8.252000
# Thriller              37      8.229730
# Biography             25      8.216000
# Animation             22      8.213636
# Romance               22      8.213636
# History               15      8.206667
# Film-Noir              5      8.200000
# Comedy                44      8.190909
# Sport                  5      8.100000
# Musical                3      8.066667

# %%
df.loc[df['genres'].apply(lambda row: 'drama' in [x.lower() for x in row]), ['name', 'genres']]
# Out:
#                                                   name  \
# 0                             The Shawshank Redemption
# 1                                        The Godfather
# 2                               The Godfather: Part II
# 3                                      The Dark Knight
# 4                                         12 Angry Men
# 5                                     Schindler's List
# 6        The Lord of the Rings: The Return of the King
# 7                                         Pulp Fiction
# 9                                           Fight Club
# 10   The Lord of the Rings: The Fellowship of the Ring
# 11                                        Forrest Gump
# 12                                               Joker
# 15               The Lord of the Rings: The Two Towers
# 17                     One Flew Over the Cuckoo's Nest
# 18                                          Goodfellas
# 19                                Shichinin no samurai
# 20                                               Se7en
# 21                                      Cidade de Deus
# 22                                     La vita è bella
# 23                            The Silence of the Lambs
# 24                               It's a Wonderful Life
# 26                                 Saving Private Ryan
# 28                                      The Green Mile
# 29                                                Léon
# 30                                        Interstellar
# 31                                             Seppuku
# 33                                       The Lion King
# 34                                  American History X
# 36                                         The Pianist
# 37                                        Modern Times
# ..                                                 ...
# 212                                              Logan
# 213                                       Barry Lyndon
# 214                                            Ben-Hur
# 216                                       Hotel Rwanda
# 217                                      Amores perros
# 218                                         White Heat
# 219       Harry Potter and the Deathly Hallows: Part 2
# 220                             Les quatre cents coups
# 221                                          Spotlight
# 222                                    Ace in the Hole
# 223                                 Dead Poets Society
# 224                                            Rebecca
# 225                                              Rocky
# 229                                           La haine
# 230                                          Ah-ga-ssi
# 231                  Lagaan: Once Upon a Time in India
# 233                                Munna Bhai M.B.B.S.
# 234                                                 PK
# 235                 Butch Cassidy and the Sundance Kid
# 236                                      Before Sunset
# 237                                           The Help
# 238                             Swades: We, the People
# 239                                              Akira
# 241                                   Faa yeung nin wa
# 242                                       Paris, Texas
# 243                              El ángel exterminador
# 246                                       Mou gaan dou
# 247                             La battaglia di Algeri
# 248                             Tenkû no shiro Rapyuta
# 249                                        Kumonosu-jô
#
#                             genres
# 0                          [Drama]
# 1                   [Crime, Drama]
# 2                   [Crime, Drama]
# 3           [Action, Crime, Drama]
# 4                          [Drama]
# 5      [Biography, Drama, History]
# 6      [Adventure, Drama, Fantasy]
# 7                   [Crime, Drama]
# 9                          [Drama]
# 10     [Adventure, Drama, Fantasy]
# 11                [Drama, Romance]
# 12        [Crime, Drama, Thriller]
# 15     [Adventure, Drama, Fantasy]
# 17                         [Drama]
# 18       [Biography, Crime, Drama]
# 19              [Adventure, Drama]
# 20         [Crime, Drama, Mystery]
# 21                  [Crime, Drama]
# 22        [Comedy, Drama, Romance]
# 23        [Crime, Drama, Thriller]
# 24        [Drama, Family, Fantasy]
# 26                    [Drama, War]
# 28         [Crime, Drama, Fantasy]
# 29          [Action, Crime, Drama]
# 30      [Adventure, Drama, Sci-Fi]
# 31                [Drama, History]
# 33   [Animation, Adventure, Drama]
# 34                         [Drama]
# 36       [Biography, Drama, Music]
# 37         [Comedy, Drama, Family]
# ..                             ...
# 212        [Action, Drama, Sci-Fi]
# 213    [Adventure, Drama, History]
# 214    [Adventure, Drama, History]
# 216    [Biography, Drama, History]
# 217              [Drama, Thriller]
# 218         [Action, Crime, Drama]
# 219    [Adventure, Drama, Fantasy]
# 220                 [Crime, Drama]
# 221      [Biography, Crime, Drama]
# 222             [Drama, Film-Noir]
# 223                [Comedy, Drama]
# 224      [Drama, Mystery, Romance]
# 225                 [Drama, Sport]
# 229                 [Crime, Drama]
# 230     [Drama, Romance, Thriller]
# 231    [Adventure, Drama, Musical]
# 233       [Comedy, Drama, Musical]
# 234       [Comedy, Drama, Fantasy]
# 235      [Biography, Crime, Drama]
# 236               [Drama, Romance]
# 237                        [Drama]
# 238                        [Drama]
# 239     [Animation, Drama, Sci-Fi]
# 241               [Drama, Romance]
# 242                        [Drama]
# 243               [Drama, Fantasy]
# 246        [Crime, Drama, Mystery]
# 247                   [Drama, War]
# 248  [Animation, Adventure, Drama]
# 249               [Drama, History]
#
# [181 rows x 2 columns]

# %%
df = merged.copy()

all_directors = set(name for n in df['directors'] for name in n)
stats = [
    [name, df.loc[df['directors'].apply(lambda row: name in row), 'directors'].count()]
    for name in all_directors
]

director_stats = pd.DataFrame(columns=['name', 'count_movies'], data=stats)
others = director_stats.loc[(director_stats.count_movies<=2) | (director_stats.name == '1 more credit')]
director_stats.drop(others.index, inplace=True)
director_stats.set_index('name', inplace=True)
director_stats.sort_values(by='count_movies', inplace=True, ascending=False)
# director_stats.loc['others'] = others.count()
director_stats
# Out:
#                       count_movies
# name
# Stanley Kubrick                  7
# Christopher Nolan                7
# Martin Scorsese                  7
# Hayao Miyazaki                   6
# Steven Spielberg                 6
# Akira Kurosawa                   6
# Billy Wilder                     6
# Alfred Hitchcock                 6
# Quentin Tarantino                5
# Charles Chaplin                  5
# Sergio Leone                     4
# Lee Unkrich                      3
# Joel Coen                        3
# Rajkumar Hirani                  3
# Ridley Scott                     3
# Pete Docter                      3
# Ingmar Bergman                   3
# David Fincher                    3
# James Cameron                    3
# Frank Capra                      3
# Ethan Coen                       3
# Clint Eastwood                   3
# Peter Jackson                    3
# Francis Ford Coppola             3

# %%
fig, (counts_axis, directors_axis) = plt.subplots(1, 2, figsize=(20, 10))
counts_axis.set_title("Number of Movies per genre")
counts_axis.pie(genre_stats['count_ratings'], labels=genre_stats.index);
directors_axis.set_title("Number of movies for directors with #movies>2")
directors_axis.pie(director_stats['count_movies'], labels=director_stats.index);

# %% [markdown]
# ## Budget
#
# Make a scatter plot with movies length and budget as the x and y axes. Since the budgets are not adjusted for inflation, to approximate that, color code the data points so that the movies that are released in the same decade have the same color. Use `alpha` parameter to make the points 50% transparent so that overlapping points are better visible. Set the proper axis labels and chart title. Also add a `colorbar` to show which color is associated with which decade. (15 points)

# %%
df = merged.loc[:, ('name', 'release_year', 'budget', 'length')].copy()
df['decade'] = df['release_year'].apply(lambda year: 10*int(year/10))
df.drop('release_year', axis=1, inplace=True)
df
# Out:
#                                                   name       budget  length  \
# 0                             The Shawshank Redemption   25000000.0     142
# 1                                        The Godfather    6000000.0     175
# 2                               The Godfather: Part II   13000000.0     202
# 3                                      The Dark Knight  185000000.0     152
# 4                                         12 Angry Men     350000.0      96
# 5                                     Schindler's List   22000000.0     195
# 6        The Lord of the Rings: The Return of the King   94000000.0     201
# 7                                         Pulp Fiction    8000000.0     154
# 8                      Il buono, il brutto, il cattivo    1200000.0     161
# 9                                           Fight Club   63000000.0     139
# 10   The Lord of the Rings: The Fellowship of the Ring   93000000.0     178
# 11                                        Forrest Gump   55000000.0     142
# 12                                               Joker   55000000.0     122
# 13                                           Inception  160000000.0     148
# 14      Star Wars: Episode V - The Empire Strikes Back   18000000.0     124
# 15               The Lord of the Rings: The Two Towers   94000000.0     179
# 16                                          The Matrix   63000000.0     136
# 17                     One Flew Over the Cuckoo's Nest    3000000.0     133
# 18                                          Goodfellas   25000000.0     146
# 19                                Shichinin no samurai          NaN     207
# 20                                               Se7en   33000000.0     127
# 21                                      Cidade de Deus    3300000.0     130
# 22                                     La vita è bella   20000000.0     116
# 23                            The Silence of the Lambs   19000000.0     118
# 24                               It's a Wonderful Life    3180000.0     130
# 25                                           Star Wars   11000000.0     121
# 26                                 Saving Private Ryan   70000000.0     169
# 27                       Sen to Chihiro no kamikakushi   19000000.0     125
# 28                                      The Green Mile   60000000.0     189
# 29                                                Léon          NaN     110
# ..                                                 ...          ...     ...
# 220                             Les quatre cents coups          NaN      99
# 221                                          Spotlight   20000000.0     129
# 222                                    Ace in the Hole    1800000.0     111
# 223                                 Dead Poets Society   16400000.0     128
# 224                                            Rebecca    1288000.0     130
# 225                                              Rocky     960000.0     120
# 226                                     Monsters, Inc.  115000000.0      92
# 227                              It Happened One Night     325000.0     105
# 228                                 Gangs of Wasseypur          NaN     321
# 229                                           La haine          NaN      98
# 230                                          Ah-ga-ssi          NaN     145
# 231                  Lagaan: Once Upon a Time in India    6000000.0     224
# 232                                 The Princess Bride   16000000.0      98
# 233                                Munna Bhai M.B.B.S.          NaN     156
# 234                                                 PK          NaN     153
# 235                 Butch Cassidy and the Sundance Kid    6000000.0     110
# 236                                      Before Sunset    2700000.0      80
# 237                                           The Help   25000000.0     146
# 238                             Swades: We, the People          NaN     210
# 239                                              Akira          NaN     124
# 240                                     The Terminator    6400000.0     107
# 241                                   Faa yeung nin wa          NaN      98
# 242                                       Paris, Texas          NaN     145
# 243                              El ángel exterminador          NaN      95
# 244                                            Aladdin   28000000.0      90
# 245                            Guardians of the Galaxy  170000000.0     121
# 246                                       Mou gaan dou    6428966.0     101
# 247                             La battaglia di Algeri     800000.0     121
# 248                             Tenkû no shiro Rapyuta          NaN     125
# 249                                        Kumonosu-jô          NaN     110
#
#      decade
# 0      1990
# 1      1970
# 2      1970
# 3      2000
# 4      1950
# 5      1990
# 6      2000
# 7      1990
# 8      1960
# 9      1990
# 10     2000
# 11     1990
# 12     2010
# 13     2010
# 14     1980
# 15     2000
# 16     1990
# 17     1970
# 18     1990
# 19     1950
# 20     1990
# 21     2000
# 22     1990
# 23     1990
# 24     1940
# 25     1970
# 26     1990
# 27     2000
# 28     1990
# 29     1990
# ..      ...
# 220    1950
# 221    2010
# 222    1950
# 223    1980
# 224    1940
# 225    1970
# 226    2000
# 227    1930
# 228    2010
# 229    1990
# 230    2010
# 231    2000
# 232    1980
# 233    2000
# 234    2010
# 235    1960
# 236    2000
# 237    2010
# 238    2000
# 239    1980
# 240    1980
# 241    2000
# 242    1980
# 243    1960
# 244    1990
# 245    2010
# 246    2000
# 247    1960
# 248    1980
# 249    1950
#
# [250 rows x 4 columns]

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 10))
plt.style.use('seaborn-whitegrid')

number_of_unique_decades = df['decade'].unique().shape[0]
color_map = plt.get_cmap('jet', number_of_unique_decades)
s = ax.scatter(df['length'], df['budget'], c=df['decade'], alpha=0.5, cmap=color_map);
ax.set_title('Movie budget vs. movie length');
ax.set_xlabel('Movie length (minutes)');
ax.set_ylabel('Budget $');
fig.colorbar(s, ax=ax)
